# %%
import pandas as pd

# %%
pd.read_csv('dataset/Student_Marks.csv')
#(r'drag&drop file tersebut kesini)
# Out:
#     number_courses  time_study   Marks
# 0                3       4.508  19.202
# 1                4       0.096   7.734
# 2                4       3.133  13.811
# 3                6       7.909  53.018
# 4                8       7.811  55.299
# ..             ...         ...     ...
# 95               6       3.561  19.128
# 96               3       0.301   5.609
# 97               4       7.163  41.444
# 98               7       0.309  12.027
# 99               3       6.335  32.357
#
# [100 rows x 3 columns]

# %%
pd.read_csv('dataset/contoh.csv', delimiter=";")
# Out:
#    kol1  kol2  kol3
# 0     1     3     3
# 1     6     2     8
# 2     2     8     9

# %%
df = pd.read_csv('nbaallelo.csv')

# %%
pd.read_csv('https://raw.githubusercontent.com/ardhiraka/PFDS_sources/master/nbaallelo.csv')
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# 0                1            0     TRH    Huskies  ...  40.294830     NYK
# ...

# %%
# Menunjukan jumlah kolom dan baris
df.shape
# Out:
# (126314, 23)

# %%
#Mengambil data n teratas
df.head(15)
# Out:
#     gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0           1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1           1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2           2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3           2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4           3  194611020DTF   NBA        0     1947  11/2/1946           1
# 5           3  194611020DTF   NBA        1     1947  11/2/1946           1
# 6           4  194611020PRO   NBA        1     1947  11/2/1946           1
# 7           4  194611020PRO   NBA        0     1947  11/2/1946           1
# 8           5  194611020STB   NBA        1     1947  11/2/1946           1
# 9           5  194611020STB   NBA        0     1947  11/2/1946           1
# 10          6  194611030CLR   NBA        1     1947  11/3/1946           2
# ...

# %%
# Mensetting jumlah kolom n yang ditampilkan
pd.set_option("display.max.columns", None)
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0000  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0000  1309.6521  42.012257    NYK
# 3            0     NYK   Knicks   47  1306.7233  1297.0712  40.692783    CHS
# 4            0     DTF  Falcons   33  1300.0000  1279.6189  38.864048    WSC
#
# ...

# %%
# menunjukan data terbawah
df.tail()
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# 126309         100            1     CLE  Cavaliers   82  1723.4149  1704.3949
# 126310         102            1     GSW   Warriors  104  1809.9791  1813.6349
# 126311         101            1     CLE  Cavaliers   91  1704.3949  1700.7391
# 126312         102            1     CLE  Cavaliers   97  1700.7391  1692.0859
# 126313         103            1     GSW   Warriors  105  1813.6349  1822.2881
#
#         win_equiv opp_id   opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# ...

# %%
# mengambil data secara random
df.sample(5)
# Out:
#        gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 41219      20610  197903010ATL   NBA        0     1979    3/1/1979
# 4555        2278  195211010GSW   NBA        1     1953   11/1/1952
# 38297      19149  197711250BOS   NBA        1     1978  11/25/1977
# 62571      31286  198912230DET   NBA        0     1990  12/23/1989
# 50008      25005  198312040SAS   NBA        1     1984   12/4/1983
#
#        seasongame  is_playoffs team_id  fran_id  pts      elo_i      elo_n  \
# 41219          64            0     ATL    Hawks  104  1555.8140  1563.0699
# 4555            1            0     SYR   Sixers   84  1565.7715  1561.8273
# 38297          17            0     NYK   Knicks  119  1513.7714  1509.8876
# 62571          26            0     DET  Pistons  106  1653.7363  1654.7002
# 50008          19            0     PHO     Suns  122  1482.6240  1505.0051
#
#        win_equiv opp_id  opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# ...

# %%
# Object pada dtype dapat berarti string dan float
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
# Gambaran dasar statistika dari masing-masing kolom
df.describe().T
# Out:
#                 count          mean           std          min           25%  \
# gameorder    126314.0  31579.000000  18231.927643     1.000000  15790.000000
# _iscopy      126314.0      0.500000      0.500002     0.000000      0.000000
# year_id      126314.0   1988.200374     17.582309  1947.000000   1975.000000
# seasongame   126314.0     43.533733     25.375178     1.000000     22.000000
# is_playoffs  126314.0      0.063857      0.244499     0.000000      0.000000
# pts          126314.0    102.729982     14.814845     0.000000     93.000000
# elo_i        126314.0   1495.236055    112.139945  1091.644500   1417.237975
# elo_n        126314.0   1495.236055    112.461687  1085.774400   1416.994900
# win_equiv    126314.0     41.707889     10.627332    10.152501     34.103035
# opp_pts      126314.0    102.729982     14.814845     0.000000     93.000000
# opp_elo_i    126314.0   1495.236055    112.139945  1091.644500   1417.237975
# ...

# %% [markdown]
# Berdasarkan overview diketahui:
# - missing value di kolom notes
# - rentang tahunnya ...
# - ditemukan kejanggalan pts bernilai 0, akan dilakukan eksplorasi lebih lanjut

# %% [markdown]
# DATA EXPLORATION

# %%
df.head(2)
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
#
#    is_playoffs team_id  fran_id  pts   elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0  1293.2767   40.29483    NYK
# 1            0     NYK   Knicks   68  1300.0  1306.7233   41.70517    TRH
#
#   opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  forecast  \
# 0   Knicks       68     1300.0  1306.7233             H           L  0.640065
# 1  Huskies       66     1300.0  1293.2767             A           W  0.359935
#
#   notes
# 0   NaN
# 1   NaN

# %%
df[['team_id','fran_id', 'year_id']]
# Out:
#        team_id    fran_id  year_id
# 0          TRH    Huskies     1947
# 1          NYK     Knicks     1947
# 2          CHS      Stags     1947
# 3          NYK     Knicks     1947
# 4          DTF    Falcons     1947
# ...        ...        ...      ...
# 126309     CLE  Cavaliers     2015
# 126310     GSW   Warriors     2015
# 126311     CLE  Cavaliers     2015
# 126312     CLE  Cavaliers     2015
# 126313     GSW   Warriors     2015
#
# [126314 rows x 3 columns]

# %%
df['team_id'].unique()
# Out:
# array(['TRH', 'NYK', 'CHS', 'DTF', 'WSC', 'BOS', 'PRO', 'PIT', 'STB',
#        'CLR', 'PHW', 'BLB', 'INJ', 'FTW', 'MNL', 'ROC', 'TRI', 'DNN',
#        'INO', 'SHE', 'WAT', 'AND', 'SYR', 'MLH', 'STL', 'DET', 'CIN',
#        'LAL', 'CHP', 'CHZ', 'SFW', 'BAL', 'PHI', 'CHI', 'SEA', 'OAK',
#        'ANA', 'SDR', 'KEN', 'INA', 'DNR', 'DLC', 'HSM', 'NOB', 'MNM',
#        'NJA', 'PTP', 'ATL', 'MIL', 'PHO', 'NYA', 'MMF', 'MNP', 'LAS',
#        'CAR', 'WSA', 'BUF', 'CLE', 'UTS', 'FLO', 'PTC', 'POR', 'VIR',
#        'TEX', 'MMP', 'HOU', 'GSW', 'KCO', 'MMT', 'SDA', 'CAP', 'SAA',
#        'NOJ', 'DNA', 'SSL', 'MMS', 'WSB', 'KCK', 'SDS', 'IND', 'NYN',
#        'DEN', 'SAS', 'NJN', 'SDC', 'UTA', 'DAL', 'LAC', 'SAC', 'CHH',
#        'MIA', 'MIN', 'ORL', 'VAN', 'TOR', 'WAS', 'MEM', 'NOH', 'CHA',
#        'NOK', 'OKC', 'BRK', 'NOP', 'CHO'], dtype=object)

# %%
df['team_id'].value_counts().head(3)
# Out:
# BOS    5997
# NYK    5769
# LAL    5078
# Name: team_id, dtype: int64

# %%
df['fran_id'].value_counts().head(3)
# Out:
# Lakers     6024
# Celtics    5997
# Knicks     5769
# Name: fran_id, dtype: int64

# %% [markdown]
# Terdapat ketidakkonsistenan antara team_id dan fran_id yang seharusnya jumlah mereka adalah sama

# %%
df.head(2)
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
#
#    is_playoffs team_id  fran_id  pts   elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0  1293.2767   40.29483    NYK
# 1            0     NYK   Knicks   68  1300.0  1306.7233   41.70517    TRH
#
#   opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  forecast  \
# 0   Knicks       68     1300.0  1306.7233             H           L  0.640065
# 1  Huskies       66     1300.0  1293.2767             A           W  0.359935
#
#   notes
# 0   NaN
# 1   NaN

# %%
df.loc[df['fran_id'] == 'Lakers', 'team_id'].head()
# Out:
# 1136    MNL
# 1152    MNL
# 1159    MNL
# 1170    MNL
# 1183    MNL
# Name: team_id, dtype: object

# %%
df.loc[df['fran_id']=='Lakers','team_id'].value_counts()
# Out:
# LAL    5078
# MNL     946
# Name: team_id, dtype: int64

# %%
5078+946
# Out:
# 6024

# %% [markdown]
# Ternyata Franchies Lakers memiliki 2 Team_id

# %%
# chaining dengan funsi agregasi
df.loc[df['fran_id']=='Lakers', 'pts'].min()
# Out:
# 18

# %% [markdown]
# QUERY

# %%
df.sample(2)
# Out:
#        gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 75639      37820  199504020CLE   NBA        1     1995    4/2/1995
# 36624      18313  197612180HOU   NBA        0     1977  12/18/1976
#
#        seasongame  is_playoffs team_id  fran_id  pts      elo_i      elo_n  \
# 75639          71            0     DEN  Nuggets  104  1548.2977  1555.2898
# 36624          26            0     HOU  Rockets  106  1518.0255  1507.5753
#
#        win_equiv opp_id   opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# 75639  46.910591    CLE  Cavaliers      101  1513.4878  1506.4957
# 36624  41.531746    NOJ       Jazz      110  1455.1952  1465.6454
#
#       game_location game_result  forecast notes
# 75639             A           W  0.407270   NaN
# 36624             H           L  0.718559   NaN

# %%
df[(df['year_id']>2000)&
    (df['year_id']<2010)&
    (df['fran_id']=='Wizards')&
    (df['pts']>80)][['year_id','fran_id','pts','game_location']]
# Out:
#         year_id  fran_id  pts game_location
# 87764      2001  Wizards   86             A
# 87778      2001  Wizards   95             A
# 87841      2001  Wizards   96             A
# 87859      2001  Wizards   88             A
# 87890      2001  Wizards   86             H
# ...         ...      ...  ...           ...
# 110682     2009  Wizards  104             H
# 110727     2009  Wizards   86             A
# 110776     2009  Wizards  100             A
# 110827     2009  Wizards   96             H
# 110834     2009  Wizards  107             A
#
# [690 rows x 4 columns]

# %%
# year_id [ 2005 - 2012]
# seasongame ganjil
# pts > 90
# game result W

# .shape

# %%
df[(df['year_id']>=2005)&
    (df['year_id']<=2012)&
    (df['seasongame'] % 2!= 0)&
    (df['pts']>90)&
    (df['game_result']=='W')
    ][['year_id','seasongame','pts','game_result']].head(5)
# Out:
#        year_id  seasongame  pts game_result
# 97887     2005           1  107           W
# 97893     2005           1   98           W
# 97895     2005           1  109           W
# 97898     2005           1  114           W
# 97901     2005           1  103           W

# %%
df.query("year_id >= 2005 & \
    year_id <= 2012 & \
    seasongame % 2 != 0 & \
    pts > 90 & \
    game_result == 'W'").shape
# Out:
# (4698, 23)

# %% [markdown]
# Grouping and Aggregating

# %%
df.groupby(by='fran_id')[['pts']].mean().sort_values(by='pts',ascending=False).head()
# Out:
#                    pts
# fran_id
# Condors     115.446512
# Squires     114.051314
# Floridians  112.654545
# Stars       112.354497
# Colonels    111.625296

# %%
df.groupby(by='game_location')['pts'].mean()
# Usahakan Group by dilakukan pada yang bersifat categorical
# Sedangkan untuk yang di aggregasi adalah numerik
# Out:
# game_location
# A    100.856616
# H    104.602395
# N    104.315789
# Name: pts, dtype: float64

# %%
grup = df.groupby('game_location')
grup

# %%
grup.get_group('H')['pts'].mean()
# Out:
# 104.60239475434761

# %%
grup.get_group('A')['pts'].mean()
# Out:
# 100.85661566726853

# %%
grup.get_group('N')['pts'].mean()
# Out:
# 104.3157894736842

# %%
df[(df['year_id']>2010)&
    (df['fran_id']=='Celtics')].groupby(by=['year_id','game_location','game_result'])[['pts']].mean()
# Out:
#                                           pts
# year_id game_location game_result
# 2011    A             L             85.095238
#                       W            101.120000
#         H             L             90.111111
#                       W            101.083333
# 2012    A             L             87.360000
#                       W             95.611111
#         H             L             82.272727
#                       W             95.062500
# 2013    A             L             90.137931
#                       W            100.333333
#         H             L             89.266667
#                       W            101.928571
# 2014    A             L             93.375000
#                       W            105.111111
#         H             L             92.640000
#                       W            102.625000
# 2015    A             L             99.125000
#                       W            103.473684
#         H             L             97.636364
# ...

# %% [markdown]
# MANIPULATING COLUMNS

# %%
nba  = df.copy()
nba.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0000  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0000  1309.6521  42.012257    NYK
# 3            0     NYK   Knicks   47  1306.7233  1297.0712  40.692783    CHS
# 4            0     DTF  Falcons   33  1300.0000  1279.6189  38.864048    WSC
#
# ...

# %%
nba.rename(columns={'game_location':'location', 'game_result': 'result'})
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# 0                1            0     TRH    Huskies   66  1300.0000  1293.2767
# ...

# %%
# masih belum mengoverwrite data sebenarnya
nba.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0000  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0000  1309.6521  42.012257    NYK
# 3            0     NYK   Knicks   47  1306.7233  1297.0712  40.692783    CHS
# 4            0     DTF  Falcons   33  1300.0000  1279.6189  38.864048    WSC
#
# ...

# %%
# Berfungsi mengoverwrite ke data sebenarnya
nba.rename(columns={'game_location':'location', 'game_result': 'result'}, inplace= True)

# %%
nba.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0000  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0000  1309.6521  42.012257    NYK
# 3            0     NYK   Knicks   47  1306.7233  1297.0712  40.692783    CHS
# 4            0     DTF  Falcons   33  1300.0000  1279.6189  38.864048    WSC
#
# ...

# %% [markdown]
# Drop Column

# %%
nba.drop(labels=['elo_i','elo_n'], axis =1)
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts  win_equiv opp_id  \
# 0                1            0     TRH    Huskies   66  40.294830    NYK
# ...

# %%
nba = nba.drop(labels=['elo_i','elo_n'], axis =1)
nba.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts  win_equiv opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies   66  40.294830    NYK    Knicks       68
# 1            0     NYK   Knicks   68  41.705170    TRH   Huskies       66
# 2            0     CHS    Stags   63  42.012257    NYK    Knicks       47
# 3            0     NYK   Knicks   47  40.692783    CHS     Stags       63
# 4            0     DTF  Falcons   33  38.864048    WSC  Capitols       50
#
#    opp_elo_i  opp_elo_n location result  forecast notes
# ...

# %% [markdown]
# CREATING COLUMN

# %%
nba['selisih_poin'] = nba ['pts'] -  nba ['opp_pts']
nba.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts  win_equiv opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies   66  40.294830    NYK    Knicks       68
# 1            0     NYK   Knicks   68  41.705170    TRH   Huskies       66
# 2            0     CHS    Stags   63  42.012257    NYK    Knicks       47
# 3            0     NYK   Knicks   47  40.692783    CHS     Stags       63
# 4            0     DTF  Falcons   33  38.864048    WSC  Capitols       50
#
#    opp_elo_i  opp_elo_n location result  forecast notes  selisih_poin
# ...

# %%
# Siapkan list kosong. untuk tempat penampung
# specify variabel yang dibutuhkan
# buat prosedur --> hasil
# hasilnya simpan ke list kosong
# loop selesai, list penuh --> kolom baru

hasil = []

# kolom pts
# kolom opp_pts
for i in range(0, len(nba)):
    selisih = nba.loc[i,'pts'] - nba.loc[i,'opp_pts']
    hasil.append(selisih)

hasil
nba['selisih_loop']=hasil
nba.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts  win_equiv opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies   66  40.294830    NYK    Knicks       68
# 1            0     NYK   Knicks   68  41.705170    TRH   Huskies       66
# 2            0     CHS    Stags   63  42.012257    NYK    Knicks       47
# 3            0     NYK   Knicks   47  40.692783    CHS     Stags       63
# 4            0     DTF  Falcons   33  38.864048    WSC  Capitols       50
#
#    opp_elo_i  opp_elo_n location result  forecast notes  selisih_poin  \
# ...

# %%
range(0, len(nba))
# Out:
# range(0, 126314)

# %%
# kolom baru hasil pertandingan
# def dunction
def hasil(selisih):
    if selisih == 0:
        return 'draw'
    elif selisih > 0:
        return 'menang'
    else:
        return 'kalah'

# %%
hasil_pertandingan = []

for i in range (0,len(nba)):
    result = hasil(nba.iloc[i,-2]) 
    hasil_pertandingan.append(result)

nba['hasil'] = hasil_pertandingan

# %%
nba['hasil'].value_counts()
# Out:
# kalah     63157
# menang    63157
# Name: hasil, dtype: int64

# %%
nba['result'].value_counts()
# Out:
# L    63157
# W    63157
# Name: result, dtype: int64

# %%
contoh = df.groupby(by='fran_id')[['pts']].mean().sort_values(by='pts',ascending=False).head()
contoh
# Out:
#                    pts
# fran_id
# Condors     115.446512
# Squires     114.051314
# Floridians  112.654545
# Stars       112.354497
# Colonels    111.625296

# %%
df.groupby(by='fran_id')[['pts']].mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='fran_id'>

# %%
contoh.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='fran_id'>
